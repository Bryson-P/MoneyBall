# %%
import pandas as pd 

dom=pd.read_csv("dom.csv",index_col=0)
dom.iloc[50]
# Out:
# Player                   AquA
# Mode                      DOM
# Team                      LAG
# Event                      LW
# Vs Who                     FL
# Date                     1/25
# Group / Bracket             G
# Map ID                 #00024
# Series ID              #00006
# Map                   Hackney
# Result                      W
# Role                       AR
# Kills                      30
# Death                      18
# K/D                      1.67
# Assists                     -
# Plus / Minus               12
# CAPs                        4
# % of team's Kills       21.7%
# % of team's Deaths      14.0%
# DEFs                        -
# Coal Kills                 10
# Alleg Kills                20
# Unnamed: 24               #51
# Unnamed: 25               NaN
# Name: nan, dtype: object

# %%
dom.head()
snd=pd.read_csv("snd.csv",index_col=0)

# %%
snd.iloc[10]
# Out:
# Player                 Octane
# Team                      SEA
# Event                      LW
# Vs Who                     FL
# Date                     1/24
# Group / Bracket             G
# Map ID                 #00006
# Series ID              #00002
# Map                Gun Runner
# Result                      L
# Kills                       4
# Death                       8
# K/D                       0.5
# Plus / Minus               -4
# Plants                      0
# Defuses                     0
# OpDuel Won                  1
# OpDuel Lost                 1
# OpDuel %               50.00%
# AtkOpD Won                  0
# AtkOpD Lost                 1
# DefOpD Won                  1
# DefOpD Lost                 0
# KpR                      0.44
# DpR                      0.89
# Rounds                      9
# Snipes                    NaN
# Ranking                   #11
# Unnamed: 29               NaN
# Name: nan, dtype: object

# %%
hp=pd.read_csv("hardpoint.csv")

hp.iloc[10]
hp
# Out:
#       Unnamed: 0       Player Mode  Team Event Vs Who        Date  \
# 0            NaN      Arcitys   HP   CHI    LW    DAL        1/24
# 1            NaN      Arcitys   HP   CHI    LW    DAL        1/24
# 2            NaN        Alexx   HP   MIN    LW    LAG        1/24
# 3            NaN        GodRx   HP   MIN    LW    LAG        1/24
# 4            NaN      Assault   HP   MIN    LW    LAG        1/24
# 5            NaN      Crimsix   HP   DAL    LW    CHI        1/24
# 6            NaN      Assault   HP   MIN    LW    LAG        1/24
# 7            NaN    Lacefield   HP   LAG    LW    MIN        1/24
# 8            NaN       Formal   HP   CHI    LW    DAL        1/24
# 9            NaN        Scump   HP   CHI    LW    DAL        1/24
# 10           NaN       Saints   HP   LAG    LW    MIN        1/24
# 11           NaN       Formal   HP   CHI    LW    DAL        1/24
# 12           NaN         Asim   HP   MIN    LW    LAG        1/24
# ...

# %%
hp
# Out:
#       Unnamed: 0       Player Mode  Team Event Vs Who        Date  \
# 0            NaN      Arcitys   HP   CHI    LW    DAL        1/24
# 1            NaN      Arcitys   HP   CHI    LW    DAL        1/24
# 2            NaN        Alexx   HP   MIN    LW    LAG        1/24
# 3            NaN        GodRx   HP   MIN    LW    LAG        1/24
# 4            NaN      Assault   HP   MIN    LW    LAG        1/24
# 5            NaN      Crimsix   HP   DAL    LW    CHI        1/24
# 6            NaN      Assault   HP   MIN    LW    LAG        1/24
# 7            NaN    Lacefield   HP   LAG    LW    MIN        1/24
# 8            NaN       Formal   HP   CHI    LW    DAL        1/24
# 9            NaN        Scump   HP   CHI    LW    DAL        1/24
# 10           NaN       Saints   HP   LAG    LW    MIN        1/24
# 11           NaN       Formal   HP   CHI    LW    DAL        1/24
# 12           NaN         Asim   HP   MIN    LW    LAG        1/24
# ...
